# %%
# OS modules
from pathlib import Path

# Dependencies
from sodapy import Socrata
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import geopandas as gpd
import plotly.express as px

# VisualConfiguration
sns.set_theme(style="ticks", color_codes=True)

# Misc
import warnings
warnings.filterwarnings('ignore')

# %%
# Location of stored dataset
dataset_path = Path('../datasets/chicago-crime-data.csv')

if dataset_path.exists():
    print(f"File found: {dataset_path.name}")
else:
    load_crime_dataset()
# Out:
# File found: chicago-crime-data.csv

# %%
# Converting result into dataframe
crime_df = pd.read_csv(dataset_path)

# Convert date column to datetime format
crime_df['date'] = pd.to_datetime(crime_df['date'])

print(crime_df.shape)
print(crime_df.columns)
crime_df.head(4)
# Out:
# (1408934, 22)
# Index(['id', 'case_number', 'date', 'block', 'iucr', 'primary_type',
#        'description', 'location_description', 'arrest', 'domestic', 'beat',
#        'district', 'ward', 'community_area', 'fbi_code', 'year', 'updated_on',
#        'x_coordinate', 'y_coordinate', 'latitude', 'longitude', 'location'],
#       dtype='object')
#          id case_number                date              block  iucr  \
# 0  11641644    JC207234 2019-03-31 09:30:00  005XX N ogden ave  0890
# 1  11642710    JC209088 2019-03-31 01:00:00   015XX N WELLS ST  0890
# 2  11642709    JC208560 2019-03-31 11:00:00  0000X E MONROE ST  0890
# 3  11641640    JC207466 2019-03-31 12:30:00  037XX W Ogden Ave  0820
#
#   primary_type     description location_description  arrest  domestic  ...  \
# 0        THEFT   FROM BUILDING           RESTAURANT   False     False  ...
# 1        THEFT   FROM BUILDING        BAR OR TAVERN   False     False  ...
# 2        THEFT   FROM BUILDING          HOTEL/MOTEL   False     False  ...
# 3        THEFT  $500 AND UNDER        ATHLETIC CLUB   False     False  ...
#
#    ward  community_area  fbi_code  year               updated_on  \
# 0   1.0            24.0        06  2019  2019-04-07T16:05:59.000
# 1  27.0             8.0        06  2019  2019-04-07T16:05:59.000
# 2  42.0            32.0        06  2019  2019-04-07T16:05:59.000
# 3  24.0            29.0        06  2019  2019-04-07T16:05:59.000
#
#    x_coordinate y_coordinate  latitude  longitude  location
# 0           NaN          NaN       NaN        NaN       NaN
# 1           NaN          NaN       NaN        NaN       NaN
# 2           NaN          NaN       NaN        NaN       NaN
# 3           NaN          NaN       NaN        NaN       NaN
#
# [4 rows x 22 columns]

# %%
com_trend = pd.read_csv("../assets/maps/community_trend.csv")

# %%
com_trend
# Out:
#          Community Most Frequent Crime  total_crimes  total_arrests  \
# 0      ALBANY PARK               THEFT         12779           1423
# 1   ARCHER HEIGHTS               THEFT          5095            451
# 2    ARMOUR SQUARE               THEFT          5971            732
# 3          ASHBURN               THEFT         12383            981
# 4   AUBURN GRESHAM             BATTERY         38415           6210
# ..             ...                 ...           ...            ...
# 72       WEST LAWN               THEFT          9308            950
# 73    WEST PULLMAN             BATTERY         21227           3202
# 74      WEST RIDGE               THEFT         20482           1936
# 75       WEST TOWN               THEFT         39384           3425
# 76        WOODLAWN             BATTERY         19372           2576
#
#     Arrest Rate
# 0         11.14
# 1          8.85
# 2         12.26
# 3          7.92
# 4         16.17
# ..          ...
# 72        10.21
# 73        15.08
# 74         9.45
# 75         8.70
# 76        13.30
#
# [77 rows x 5 columns]

# %%
community_df = pd.read_csv('../assets/maps/comm-areas.csv')
community_df.columns
# Out:
# Index(['the_geom', 'PERIMETER', 'AREA', 'COMAREA_', 'COMAREA_ID', 'AREA_NUMBE',
#        'COMMUNITY', 'AREA_NUM_1', 'SHAPE_AREA', 'SHAPE_LEN'],
#       dtype='object')

# %%
crime_df = crime_df.rename(columns={'community_area': 'community_number'})
community_df = community_df.rename(columns={'AREA_NUM_1': 'community_number','COMMUNITY': 'community_name'})
crime_df = crime_df.merge(community_df[['community_name', 'community_number']], on='community_number', how='left')

# %%
crime_df = crime_df.merge(com_trend, left_on='community_name',right_on="Community", how='right')

# %%
crime_df = crime_df.drop('community_name', axis=1)

# %%
crime_df.columns
# Out:
# Index(['id', 'case_number', 'date', 'block', 'iucr', 'primary_type',
#        'description', 'location_description', 'arrest', 'domestic', 'beat',
#        'district', 'ward', 'community_number', 'fbi_code', 'year',
#        'updated_on', 'x_coordinate', 'y_coordinate', 'latitude', 'longitude',
#        'location', 'Community', 'Most Frequent Crime', 'total_crimes',
#        'total_arrests', 'Arrest Rate'],
#       dtype='object')

# %%
crime_df.to_csv('D:/DPA/Project/dataset/crime_df.csv',index=False)
